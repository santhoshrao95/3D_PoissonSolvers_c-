# %%
import csv
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

#from mpl_toolkits import mplot3d
import numpy as np
#import matplotlib.pyplot as plt
import math

def f(x, z):
    
    return 500*np.exp(-50*((1-x)**2 + z**2)) + 100*x*(1-z)


x = np.linspace(0, 1, 33)
z = np.linspace(0, 1, 33)

X, Z = np.meshgrid(x, z)
phi1 = f(X, Z)
#print(phi)
ax = plt.axes(projection='3d')
ax.plot_surface(X,Z,phi1[:], rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('Exact_3d')


ax.set_xlim(0,1)
ax.set_ylim(0,1)
ax.set_xlabel('$x$')
ax.set_ylabel('$z$')
ax.set_zlabel('$phi$')
#ax.view_init(20,20)
plt.savefig('Exact_3D.png')
ax.view_init(30,-70)

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

#from mpl_toolkits import mplot3d
import numpy as np
#import matplotlib.pyplot as plt
import math

with open('gs_33_5000_j=16.csv') as inf:
    phi = []
   # y1 = []
    for line in csv.reader(inf):
        tx =  line
        tx = [float(i) for i in tx]
        phi.append(tx)
#print(phi)


x = np.linspace(0, 1, 33)
z = np.linspace(0, 1, 33)

X, Z = np.meshgrid(x, z)
#phi = f(X, Z)
y = np.array(phi)
#print(phi)
ax = plt.axes(projection='3d')
ax.plot_surface(X,Z,y[:], rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
#ax.set_title('surface')


ax.set_xlim(0,1)
ax.set_ylim(0,1)
ax.set_xlabel('$x$')
ax.set_ylabel('$z$')
ax.set_zlabel('$phi$')
ax.set_title('GS_j=16_33*33*33')
plt.savefig('GS_j=16_33*33*33_3d.png')
ax.view_init(30,-70)

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

#from mpl_toolkits import mplot3d
import numpy as np
#import matplotlib.pyplot as plt
import math

with open('gs_63_5000_j=31.csv') as inf:
    phi = []
   # y1 = []
    for line in csv.reader(inf):
        tx =  line
        tx = [float(i) for i in tx]
        phi.append(tx)
#print(phi)


x = np.linspace(0, 1, 63)
z = np.linspace(0, 1, 63)

X, Z = np.meshgrid(x, z)
#phi = f(X, Z)
y = np.array(phi)
#print(phi)
ax = plt.axes(projection='3d')
ax.plot_surface(X,Z,y[:], rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
#ax.set_title('surface')


ax.set_xlim(0,1)
ax.set_ylim(0,1)
ax.set_xlabel('$x$')
ax.set_ylabel('$z$')
ax.set_zlabel('$phi$')
ax.set_title('GS_j=31_63*63*63')
plt.savefig('GS_j=31_63*63*63_3d.png')
ax.view_init(30,-70)

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
import math

def f(x, z):
    
    return 500*np.exp(-50*((1-x)**2 + z**2)) + 100*x*(1-z)


x = np.linspace(0, 1, 30)
z = np.linspace(0, 1, 30)

X, Z = np.meshgrid(x, z)
phi = f(X, Z)
fig = plt.figure(figsize=(6,5))
left, bottom, width, height = 0.1, 0.1, 0.8, 0.8
ax = fig.add_axes([left, bottom, width, height])

cp = ax.contour(X, Z, phi)
ax.clabel(cp, inline=True,fontsize=10)
ax.set_title('Exact_countour')
plt.savefig('Exact_countour.png')
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

#from mpl_toolkits import mplot3d
import numpy as np
#import matplotlib.pyplot as plt
import math

with open('gs_33_5000_j=16.csv') as inf:
    phi = []
   # y1 = []
    for line in csv.reader(inf):
        tx =  line
        tx = [float(i) for i in tx]
        phi.append(tx)
#print(phi)


x = np.linspace(0, 1, 33)
z = np.linspace(0, 1, 33)

X, Z = np.meshgrid(x, z)
y = np.array(phi)


fig = plt.figure(figsize=(6,5))
left, bottom, width, height = 0.1, 0.1, 0.8, 0.8
ax = fig.add_axes([left, bottom, width, height])

cp = ax.contour(X, Z, y)
ax.clabel(cp, inline=True,fontsize=10)

ax.set_title('GS_j=16_33*33*33')
plt.savefig('GS_j=16_33*33*33_contour.png')

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

#from mpl_toolkits import mplot3d
import numpy as np
#import matplotlib.pyplot as plt
import math


with open('gs_63_5000_j=31.csv') as inf:
    phi = []
   # y1 = []
    for line in csv.reader(inf):
        tx =  line
        tx = [float(i) for i in tx]
        phi.append(tx)
#print(phi)


x = np.linspace(0, 1, 63)
z = np.linspace(0, 1, 63)

X, Z = np.meshgrid(x, z)
y = np.array(phi)


fig = plt.figure(figsize=(6,5))
left, bottom, width, height = 0.1, 0.1, 0.8, 0.8
ax = fig.add_axes([left, bottom, width, height])

cp = ax.contour(X, Z, y)
ax.clabel(cp, inline=True,fontsize=10)

ax.set_title('GS_j=31_63*63*63')
plt.savefig('GS_j=31_63*63*63_contour.png')

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

#from mpl_toolkits import mplot3d
import numpy as np
#import matplotlib.pyplot as plt
import math


with open('gs_63_5000_j=30.csv') as inf:
    phi = []
   # y1 = []
    for line in csv.reader(inf):
        tx =  line
        tx = [float(i) for i in tx]
        phi.append(tx)
#print(phi)


x = np.linspace(0, 1, 63)
z = np.linspace(0, 1, 63)

X, Z = np.meshgrid(x, z)
y = np.array(phi)


fig = plt.figure(figsize=(6,5))
left, bottom, width, height = 0.1, 0.1, 0.8, 0.8
ax = fig.add_axes([left, bottom, width, height])

cp = ax.contour(X, Z, y)
ax.clabel(cp, inline=True,fontsize=10)

ax.set_title('GS_j=30_63*63*63')
plt.savefig('GS_j=30_63*63*63_contour.png')
